# %%
pip install pyodbc
# Out:
# ...
#      -------------------------------------- 69.4/69.4 kB 180.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyodbc

# %%
# Connection settings
server = "203.171.28.250"
database = "ANALYTICS"
username = "namba"
password = "R2YUUCR7xN4aF5"

conn = pyodbc.connect(
    f"DRIVER={{SQL Server}};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"UID={username};"
    f"PWD={password}"
)

query = """
SELECT *
FROM dbo.test1
"""

df = pd.read_sql(query, conn)

df.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17264\2044099172.py:23: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#      PR_DETAIL_ID                                     PR_DETAIL_NAME  \
# 0            0000                                             None 1
# 1  0105251191-004  Chi Nhánh Công Ty TNHH Hầm Rượu Châu Á Thành P...
# 2  0107543457-001              Chi Nhánh Công Ty TNHH Rada Việt Nam
# 3      0108076170         Công Ty TNHH TM và Sự Kiện Như Ý Cát Tường
# 4      0108783652                 Công Ty Cổ Phần Phát Triển Dũng Hà
#
#   PR_DETAIL_TYPE_ID PR_DETAIL_CLASS_ID  \
# 0                05                 NV
# 1                01                NCC
# 2                01                NCC
# 3                01                NCC
# 4                01                NCC
#
# ...

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)']
